# %% [markdown]
# # 4.4 Data Wrangling and Subsetting

# %% [markdown]
# ### Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing data sets

# %%
# Creating path variable
path = r'C:\Users\lisa_\02\2023 Instacart Basket Analysis'

# %%
# Importing data sets
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %% [markdown]
# ### Removing eval_set column from df_ords

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# Removing eval_set column from df_ords
df_ords = df_ords.drop(columns = ['eval_set'])
df_ords
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %% [markdown]
# ## 4.4.2 Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
# Changing data type to string
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['user_id'] = df_ords['user_id'].astype('str')
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ## 4.4.3 Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the data frame.

# %%
# Renaming columns
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## 4.4.4 Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.

# %%
# Count frequency of orders by hour of day
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# ### - The busiest hour for placing orders in 10am.

# %% [markdown]
# ## Transposing df_dep

# %%
# Transposing df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#Adding an index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of the def_dep_t for the header
new_header = df_dep_t.iloc[0]
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
df_dep_t_new = df_dep_t[1:]
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %% [markdown]
# ## Creating data dictionary

# %%
# Create data dictionary
data_dict = df_dep_t_new.to_dict('index')
data_dict
# Out:
# {'1': {0: 'frozen'},
#  '2': {0: 'other'},
#  '3': {0: 'bakery'},
#  '4': {0: 'produce'},
#  '5': {0: 'alcohol'},
#  '6': {0: 'international'},
#  '7': {0: 'beverages'},
#  '8': {0: 'pets'},
#  '9': {0: 'dry goods pasta'},
#  '10': {0: 'bulk'},
#  '11': {0: 'personal care'},
#  '12': {0: 'meat seafood'},
#  '13': {0: 'pantry'},
#  '14': {0: 'breakfast'},
#  '15': {0: 'canned goods'},
#  '16': {0: 'dairy eggs'},
#  '17': {0: 'household'},
#  '18': {0: 'babies'},
#  '19': {0: 'snacks'},
#  '20': {0: 'deli'},
#  '21': {0: 'missing'}}

# %% [markdown]
# ## 4.4.5 Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.

# %%
print(data_dict.get('4'))
# Out:
# {0: 'produce'}

# %% [markdown]
# ### - The value 4 in the department_id column in the df-prods data frame is "produce".

# %% [markdown]
# ## 4.4.6 The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.

# %%
data_dict
# Out:
# {'1': {0: 'frozen'},
#  '2': {0: 'other'},
#  '3': {0: 'bakery'},
#  '4': {0: 'produce'},
#  '5': {0: 'alcohol'},
#  '6': {0: 'international'},
#  '7': {0: 'beverages'},
#  '8': {0: 'pets'},
#  '9': {0: 'dry goods pasta'},
#  '10': {0: 'bulk'},
#  '11': {0: 'personal care'},
#  '12': {0: 'meat seafood'},
#  '13': {0: 'pantry'},
#  '14': {0: 'breakfast'},
#  '15': {0: 'canned goods'},
#  '16': {0: 'dairy eggs'},
#  '17': {0: 'household'},
#  '18': {0: 'babies'},
#  '19': {0: 'snacks'},
#  '20': {0: 'deli'},
#  '21': {0: 'missing'}}

# %%
# Create subset for breakfast items
df_breakfast =  df_prods[df_prods['department_id']==14]
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# ## 4.4.7 They’d also like to see details about customers who might be throwing dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

# %%
# Create subset for dinner parties
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]
df_dinner_party.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %% [markdown]
# ## 4.4.8 It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

# %%
df_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# ### - The dinner party data frame has 3,285 rows.

# %% [markdown]
# ## 4.4.9 Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
# Create a subset for user_id 1
df_user_1 = df_ords.loc[df_ords['user_id']==1]

# %%
df_user_1
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# ## 4.4.10 You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %%
# User_id 1 statistics
df_user_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count           0.0                 0.0                0.0
# mean            NaN                 NaN                NaN
# std             NaN                 NaN                NaN
# min             NaN                 NaN                NaN
# 25%             NaN                 NaN                NaN
# 50%             NaN                 NaN                NaN
# 75%             NaN                 NaN                NaN
# max             NaN                 NaN                NaN
#
#        days_since_prior_order
# count                     0.0
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %% [markdown]
# ## 4.4.12 Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.

# %%
# Export df_ords dataframe to Prepared Data folder
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# ## Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.

# %%
# Export df_dep_t_new dataframe to Prepared Data folder
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %%
df_ords.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.715486e+01        2.776219e+00       1.345202e+01
# std    1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.300000e+01        5.000000e+00       1.600000e+01
# max    1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01
